# %% [markdown]
# ![rWbHIOI33GQ.jpg](data:image/jpeg;base64,...)

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_01.
#
# Выполнил: Олифир А.А
# Группа: АДЭУ - 201
# E-mail: aalinanilaa@gmail.com
import math

x = float(input("x="))

if x >= 0:
    f = math.sqrt(x) + x ** 2
else:
    f = 1 / x

print(round(f,2))

# --------------
# Пример вывода:
#
# Введите число x: -10
# f = -0.10

# Введите число x: 0
# f = 0.00

# Введите число x: 10
# f = 103.16
# Out:
# x=1
# 2.0

# %% [markdown]
# № 4.2.2
#
# Определите максимальное и минимальное значения из двух различных целых чисел.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_02.
#
# Выполнил: Олифир А.А
# Группа: АДЭУ-201
# E-mail: aalinanilaa@gmail.com


a1 = int(input("a1="))
a2 = int(input("a2="))


print("максимум:", end="")

if a1 >= a2:
  print(a1)
else:
  print(a2)

print("минимум:", end="")

if a1 <= a2:
  print(a1)
else:
  print(a2)

# --------------
# Пример вывода:
#
# Введите первое число: 1
# Введите второе число: 2
# Максимум: 2, минимум: 1

# Введите первое число: 5
# Введите второе число: 5
# Максимум: 5, минимум: 5

# Введите первое число: 100
# Введите второе число: -1
# Максимум: 100, минимум: -1
# Out:
# a1=10
# a2=30
# максимум:30
# минимум:10

# %% [markdown]
# № 4.2.3
#
# Вася пытается высунуть голову в форточку размерами a и b см. Приняв условно, что его голова - круглая диаметром d см, определите, сможет ли Вася сделать это. Для прохождения головы в форточку необходим зазор в 1 см. с каждой стороны.
#
# Все величины - целые числа.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_03.
#
# Выполнил: Олифир А.А
# Группа: АДЭУ-201
# E-mail: aalinanilaa@gmail.com


a = int(input("a="))
b = int(input("b="))
d = int(input("d="))

if a > 0 and b > 0: 
  fix = 1  # Зазор
  if a >= d + 2 * fix and b >= d + 2 * fix:
    print("Да")
  else:
    print("Нет")
else:
  print("Проверьте ввод")

# --------------
# Пример вывода:
#
# Ширина форточки: 5
# Высота форточки: 6
# Диаметр головы: 6
# Нет

# Ширина форточки: 6
# Высота форточки: 7
# Диаметр головы: 4
# Да
# Out:
# a=4
# b=5
# d=3
# Нет

# %% [markdown]
# № 4.2.4
#
# Известны год и номер месяца сегодняшнего дня, а также год и номер месяца рождения человека (нумерация месяцев с 1: январь - 1 и т.д.). Определите возраст человека (число полных лет).

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_04.
#
# Выполнил: Олифир А.А
# Группа: АДЭУ-201
# E-mail: aalinanilaa@gmail.com


year_today = int(input("Введите год:"))
month_today = int(input("Введите месяц:"))

year = int(input("Введите год рождения:"))
month = int(input("Введите месяц рождения:"))

age = year_today - year
age_month = month_today - month

if age_month < 1:
  age = age - 1
  age_month = age_month + 12

print("Число полных лет:", age)

# --------------
# Пример вывода:
#
# Введите текущий год: 2017
# Введите текущий месяц: 5
# Введите год рождения: 2000
# Введите месяц рождения: 1
# Число полных лет:  17
#
# Введите текущий год: 2015
# Введите текущий месяц: 6
# Введите год рождения: 2010
# Введите месяц рождения: 8
# Число полных лет:  4
#
# Введите текущий год: 2020
# Введите текущий месяц: 5
# Введите год рождения: 2000
# Введите месяц рождения: 5
# Число полных лет:  20
# Out:
# Введите год:2020
# Введите месяц:11
# Введите год рождения:1995
# Введите месяц рождения:5
# Число полных лет: 25

# %% [markdown]
# № 4.2.5
#
# Дана точка с целыми ненулевыми координатами (x;y). Определить номер четверти координатной плоскости, которой она принадлежит.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_05.
#
# Выполнил: Фамилия И.О.
# Группа: !!!
# E-mail: !!!


x = int(input("x="))
y = int(input("y="))

if x > 0 and y > 0:
    print("1-я четверть")

if x < 0 and y > 0:
    print("2-я четверть")

if x < 0 and y < 0:
    print("3-я четверть")

if x > 0 and y < 0:
    print("4-я четверть")

# --------------
# Пример вывода:
#
# Введите координату x: 5
# Введите координату y: 7
# 1-я четверть
# Out:
# x=5
# y=-10
# 4-я четверть

# %% [markdown]
# № 4.2.6
#
# Даны вещественные числа a, b, c (a≠0).
#
# Решите уравнение ax2+bx+c=0.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_06.
#
# Выполнил: Олифир А.А
# Группа: АДЭУ-201
# E-mail: aalinanilaa@gmail.com
import math

a = float(input("a="))
b = float(input("b="))
c = float(input("c="))
print(a != 0)

# Расчет дискриминанта
d = b ** 2 - 4 * a * c

# Вывод решения в зависимости от значения дискриминанта
if d > 0:
  print("x1 = ", (- b + math.sqrt(d) / (2 * a)))
  print("x2 = ", (- b - math.sqrt(d) / (2 * a)))
elif d == 0:
  print("x = ", - b / (2 * a))
else:
  print("Корней нет")

# --------------
# Пример вывода:
#
# a = 1
# b = 2
# c = 3
# Решений нет
#
# a = 1
# b = 2
# c = 1
# x = -1.0
# Out:
# a=1
# b=2
# c=1
# True
# x =  -1.0

# %% [markdown]
# № 4.2.7
#
# Дана непустая последовательность целых чисел, оканчивающаяся нулем. Найти сумму и количество введенных чисел.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_07.
#
# Выполнил: Фамилия И.О.
# Группа: !!!
# E-mail: !!!


nums_sum = 0  # сумма
nums_count = 1  # количество

x = int(input("Введите число:"))
while x != 0:
    nums_sum = nums_sum + x
    nums_count = nums_count + 1
    x = int(input("Введите число:"))   #новое число из последовательности 

print("Сумма =", nums_sum)
print("Количество =", nums_count)

# --------------
# Пример вывода:
#
# Введите 1-е число: 1
# Введите 2-е число: 2
# Введите 3-е число: 3
# Введите 4-е число: 4
# Введите 5-е число: 0
# Сумма = 10
# Количество = 4
#
# Введите 1-е число: 0
# Сумма = 0
# Количество = 0
# Out:
# Введите число:1
# Введите число:2
# Введите число:3
# Введите число:0
# Сумма = 6
# Количество = 4

# %% [markdown]
# № 4.2.8
#
# Дано число n. Из чисел 0,5,10,15,20,25,... напечатать те, которые не превышают n.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_08.
#
# Выполнил: Фамилия И.О.
# Группа: !!!
# E-mail: !!!


n = int(input("n="))
i = 0                                   #начальное значение

while (n / 5) >= 0:
  print(i)
  i = i + 5
  n = n - 5


# --------------
# Пример вывода:
#
# n = 0
# 0
#
# n = 10
# 0
# 5
# 10
#
# n = 12
# 0
# 5
# 10
# Out:
# n=20
# 0
# 5
# 10
# 15
# 20

# %% [markdown]
# ![YCn2wO5MMN8.jpg](data:image/jpeg;base64,...)

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_09.
#
# Выполнил: Фамилия И.О.
# Группа: !!!
# E-mail: !!!


a = float(input("a="))

x_sum = 0
n = 0

while x_sum <= a:
  n = n + 1
  x_sum = x_sum + 1/n

print('n =', n)

# --------------
# Пример вывода:
#
# a = 1.5
# n = 3
#
# a = 2
# n = 4
# Out:
# a=2
# n = 4

# %% [markdown]
# № 4.2.10
#
# Дано натуральное число. Определите сумму и количество его цифр.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_10.
#
# Выполнил: Фамилия И.О.
# Группа: !!!
# E-mail: !!!


n = int(input("n="))

n_sum = 0
n_count = 0

while n > 0:
  m = n % 10                                #последняя цифра в числе
  n_sum = n_sum + m
  n_count = n_count + 1
  n = n // 10                               #шаг

print('Сумма =', n_sum)
print('Количество =', n_count)



# --------------
# Пример вывода:
#
# n = 12345
# Сумма = 15
# Количество = 5
# Out:
# n=123
# Сумма = 6
# Количество = 3

# %% [markdown]
# № 4.2.11
#
# Вывести в строку 10 первых натуральных чисел, оканчивающихся на цифру k, кратных числу s и находящихся в интервале, левая граница которого равна start.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_11.
#
# Выполнил: Фамилия И.О.
# Группа: !!!
# E-mail: !!!


start = int(input("start="))
k = int(input("k="))
s = int(input("s="))
n_count = 0

while n_count != 10:
  if (start % 10 == k) and (start % s == 0):
    print(start, end= ' ')
    n_count = n_count + 1
  start = start + 1
  
# --------------
# Пример вывода:
#
# start = 100
# k = 7
# s = 9
# 117 207 297 387 477 567 657 747 837 927
# Out:
# start=100
# k=7
# s=9
# 117 207 297 387 477 567 657 747 837 927

# %% [markdown]
# № 4.2.12
#
# Даны целые числа a и b (a может быть больше b). Напечатайте:
#
# числа от минимального до максимального в строчку (разделяя пробелом);
#
# числа от максимального до минимального «столбиком».

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_12.
#
# Выполнил: Фамилия И.О.
# Группа: !!!
# E-mail: !!!


a = int(input("a="))
b = int(input("b="))

if a > b:
  min = b
  max = a
else:
  min = a
  max = b

#от мин до макс в строчку
while min <= max:
  print(min, end= ' ')
  min = min + 1

print("\n")

if a > b:
  min = b
  max = a
else:
  min = a
  max = b

#от макс до мин в столб
while max >= min:
  print(max, end= "\n")
  max = max - 1


# --------------
# Пример вывода:
#
# a = 1
# b = 5
# 1 2 3 4 5
# 5
# 4
# 3
# 2
# 1
# Out:
# a=5
# b=6
# 5 6
#
# 6
# 5

# %% [markdown]
# № 4.2.13
#
# Для введенных с клавиатуры положительных целых чисел a и b (a≤b) определите:
#
# сумму всех целых чисел от a до b;
#
# произведение всех целых чисел от a до b;
#
# среднее арифметическое всех целых чисел от a до b;
#
# среднее геометрическое нечетных чисел от a до b.
#
# Отрезок поиска включает сами числа a и b. При выводе вещественных результатов оставьте два знака после запятой.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_13.
#
# Выполнил: Фамилия И.О.
# Группа: !!!
# E-mail: !!!
import math

a = int(input("a="))
b = int(input("b="))

if a <= 0 and b <= 0:
  print("Try again")
  
n_sum = 0
n_mult = 1   #для всех
count = 0
mult = 1     #для нечетных

while a <= b:
  count = count + 1
  n_sum = n_sum + a
  n_mult = n_mult * a
  if a % 2 != 0:
    mult = mult * a
  a = a + 1


n_avg = n_sum / count
n_avg_geom = math.sqrt(mult)


print("Сумма =", n_sum)
print("Произведение =", n_mult)
print("Среднее арифметическое =", round(n_avg, 2))
print("Среднее геометрическое нечетных чисел =", round(n_avg_geom, 2))
# Out:
# a=1
# b=5
# Сумма = 15
# Произведение = 120
# Среднее арифметическое = 3.0
# Среднее геометрическое нечетных чисел = 3.87

# %% [markdown]
# № 4.2.14
#
# Начав тренировки, лыжник в первый день пробежал s км. (s>0, вещественное число). Каждый следующий день он увеличивал пробег на p % (0<p≤100, вещественное число) от пробега предыдущего дня. Определите:
#
# пробег лыжника за второй, третий, …, десятый день тренировок;
#
# какой суммарный путь он пробежал за первые 10 дней тренировок.
#
# При выводе вещественных результатов оставьте один знак после запятой.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_14.
#
# Выполнил: Фамилия И.О.
# Группа: !!!
# E-mail: !!!


s = float(input("Пробежал за 1 - й день: "))
p = float(input("На сколько процентов увеличил: "))

total = s

for i in range(2, 11, 1):
  s = s + s * (p / 100)
  total = total + s
  print("Пробежал за ", i, "- й день: ", round(s, 3), "км")


print("Суммарный пробег: ", round(total, 3))


# --------------
# Пример вывода:
#
# Пробег за 1-й день (км.) = 5
# На сколько увеличивает пробег (%) = 10
# Пробег за 2-й день: 5.5 км.
# Пробег за 3-й день: 6.1 км.
# Пробег за 4-й день: 6.7 км.
# Пробег за 5-й день: 7.3 км.
# Пробег за 6-й день: 8.1 км.
# Пробег за 7-й день: 8.9 км.
# Пробег за 8-й день: 9.7 км.
# Пробег за 9-й день: 10.7 км.
# Пробег за 10-й день: 11.8 км.
# Суммарный пробег: 79.7 км.
# Out:
# Пробежал за 1 - й день: 15
# На сколько процентов увеличил: 10
# Пробежал за  2 - й день:  16.5 км
# Пробежал за  3 - й день:  18.15 км
# Пробежал за  4 - й день:  19.965 км
# Пробежал за  5 - й день:  21.962 км
# Пробежал за  6 - й день:  24.158 км
# Пробежал за  7 - й день:  26.573 км
# Пробежал за  8 - й день:  29.231 км
# Пробежал за  9 - й день:  32.154 км
# Пробежал за  10 - й день:  35.369 км
# Суммарный пробег:  239.061

# %% [markdown]
# № 4.2.15
#
# Известна масса каждого предмета в кг., загружаемого в грузовик. Определить, возможна ли перевозка груза, если грузоподъемность грузовика равна p кг.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_15.
#
# Выполнил: Фамилия И.О.
# Группа: !!!
# E-mail: !!!


p = int(input("p=")) # грузоподъемность
n = int(input("n=")) # кол-во предметов

total = 0 # суммарный вес всех предметов

for i in range (1, n+1, 1):
  m = int(input("Введите массу : "))
  total += m

if total > p:
  print("no")
else:
  print("yes")

# --------------
# Пример вывода:
#
# Грузоподъемность грузовика (кг.) = 10
# Количество предметов = 2
# Масса 1-го предмета (кг.) = 3
# Масса 2-го предмета (кг.) = 3
# Да
# Out:
# p=10
# n=3
# Введите массу : 3
# Введите массу : 2
# Введите массу : 1
# yes

# %% [markdown]
# № 4.2.16
#
# В области несколько районов. Заданы площади, засеваемые пшеницей (га.), и средняя урожайность (ц/га) в каждом районе.
#
# Определите количество пшеницы, собранное по области. При выводе вещественных результатов оставьте один знак после запятой.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_04_02_16.
#
# Выполнил: Фамилия И.О.
# Группа: !!!
# E-mail: !!!


n = int(input("n="))

total = 0

for i in range(1, n + 1, 1):
  s = int(input("s="))
  sr = int(input("sr="))
  total = total + s * sr

print(total)
# Out:
# n=2
# s=3
# sr=4
# s=1
# sr=4
# 16

# %% [markdown]
# № 4.2.19
#
# Выведите на экран (в строку) все целые числа от a до b, кратные некоторому числу c.

# %%
a = int(input("a="))
b = int(input("b="))
c = int(input("c="))

count = 0

for i in range(a, b + 1, 1):
  if (a % c == 0) and (b % c == 0):
    print(a, end= ' ')
    count = count + 1
  a = a + 1


# --------------
# Пример вывода:
#
# a = 1
# b = 10
# c = 2
# 2 4 6 8 10
# Out:
# a=1
# b=10
# c=2
# 2 4 6 8 10
