# %% [markdown]
# <a href="https://colab.research.google.com/github/Olifira/-/blob/main/%D0%BB%D0%B0%D0%B15_seaborn_%D0%BE%D0%BB%D0%B8%D1%84%D0%B8%D1%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Провести анализ датасетов с помощью библиотеки Seaborn(count plots)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-910f5beb-e756-4b9a-b5eb-a1f9b66e11ac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-910f5beb-e756-4b9a-b5eb-a1f9b66e11ac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving SOCR-HeightWeight.csv to SOCR-HeightWeight.csv

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
hw=pd.read_csv('SOCR-HeightWeight.csv')

# %%
hw
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 0          1        65.78331        112.9925
# 1          2        71.51521        136.4873
# 2          3        69.39874        153.0269
# 3          4        68.21660        142.3354
# 4          5        67.78781        144.2971
# ...      ...             ...             ...
# 24995  24996        69.50215        118.0312
# 24996  24997        64.54826        120.1932
# 24997  24998        64.69855        118.2655
# 24998  24999        67.52918        132.2682
# 24999  25000        68.87761        124.8742
#
# [25000 rows x 3 columns]

# %% [markdown]
# # **BOX** **PLOTS**

# %%
sns.boxplot(hw['Height(Inches)'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(hw['Weight(Pounds)'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # **VIOLIN** **PLOT**

# %%
sns.violinplot(x='Weight(Pounds)', y='Height(Inches)', data=hw)

# %% [markdown]
# # **COUNT** **PLOTS**

# %%
sns.countplot(x='Weight(Pounds)', data=hw)

# %%
sns.countplot(x='Height(Inches)', data=hw)

# %%
sns.countplot(x='Index', data=hw)

# %% [markdown]
# # **HEATMAP**

# %%
sns.heatmap(hw.corr(), annot=True, cmap='YlGnBu')

# %% [markdown]
# # **REGPLOT**

# %%
sns.regplot(x='Weight(Pounds)', y='Height(Inches)', data=hw)

# %% [markdown]
# # **Pair** **plot**

# %%
sns.pairplot(data=hw)

# %% [markdown]
# # **Join** **plot**

# %%
sns.jointplot(x='Weight(Pounds)', y='Height(Inches)', data=hw)
